# %%
import torch

# %%
from datasets import load_dataset

# %%
import sys
sys.path.append('../')

# %%
from src.utils.data import DatasetPreprocessor

# %%
from src.utils.data import POSLookup

# %%
from src.tokenizer import load_tokenizer

# %%
# setting up hydra config 
from hydra import compose, initialize
from omegaconf import OmegaConf
from src.config import BabyLMConfig 

from hydra.core.config_store import ConfigStore

cs = ConfigStore.instance()
cs.store(name="base_config", node=BabyLMConfig)

with initialize(version_base=None, config_path="../conf"):
    cfg = compose(config_name="config", overrides=[
        "experiment.group=dev", "experiment.name=test-1", "experiment.dry_run=True", "objective_curriculum=base_pos_merge",
        "dataset.subconfig=strict_small_gold",
        "pos_lookup.similarity_metric=cosine",
        ])

# %%
dataset = load_dataset(
    cfg.dataset.name,
    cfg.dataset.subconfig, 
)

# %% [markdown]
# **Loading in the tokenizer and creating a mapping of token_id to token_str**

# %%
tokenizer = load_tokenizer(cfg)

# %%
vocab_tokenizer = tokenizer._tokenizer.get_vocab()
vocab_tokenizer__key_to_token = {v: k for k, v in vocab_tokenizer.items()}

# %% [markdown]
# **Setting up the train dataset and the POS Lookup matrix**

# %%
data_preprocessor = DatasetPreprocessor(cfg, tokenizer)

train_dataset = dataset["train"].map(
    data_preprocessor,
    batched=True,
    num_proc=64,
    remove_columns=dataset["train"].column_names,
)

# %%
pos_lookup = POSLookup(train_dataset, tokenizer, similarity_metric=cfg.pos_lookup.similarity_metric)
# Out:
# 100%|██████████| 8100/8100 [00:00<00:00, 27249.63it/s]

# %% [markdown]
# Getting the sum across the 1st dimension in order to compute the total count of POS tags (total occurences of that subword).

# %%
lookup_matrix = pos_lookup.lookup_matrix
total_freq = lookup_matrix.sum(dim=1)

# %% [markdown]
# **Sorting indices by their frequencies and plotting**

# %%
sorted_pos_freq_indices = torch.argsort(total_freq, descending=True)

# %%
import matplotlib.pyplot as plt

plt.plot(total_freq[sorted_pos_freq_indices].numpy())

# %%
most_popular_tokens = sorted_pos_freq_indices[:5]
least_popular_tokens = sorted_pos_freq_indices[-5:]

print("POPULAR TOKENS")
print(10*"--")
for i in most_popular_tokens:
    print(i.item(), "---", tokenizer.convert_ids_to_tokens([i]))
    print("Frequency: ", total_freq[i].item())

print(10*"--")
print("LEAST POPULAR TOKENS")
print(10*"--")
for i in least_popular_tokens:
    print(i.item(), "---", tokenizer.convert_ids_to_tokens([i]))
    print("Frequency: ", total_freq[i].item())
print(10*"--")

# NOTE: We might also want to look at the distribution of POS tags in the dataset
# i.e. how to adjectives cluster, how do verbs cluster, etc.
# Out:
# POPULAR TOKENS
# --------------------
# 18 --- ['.']
# Frequency:  711862.0
# 16 --- [',']
# Frequency:  554378.0
# 266 --- ['Ġthe']
# Frequency:  469473.0
# 294 --- ['Ġand']
# Frequency:  230639.0
# 284 --- ['Ġto']
# Frequency:  223318.0
# --------------------
# LEAST POPULAR TOKENS
# --------------------
# 193 --- ['Ā']
# Frequency:  0.0
# 194 --- ['ā']
# Frequency:  0.0
# 195 --- ['Ă']
# Frequency:  0.0
# 196 --- ['ă']
# Frequency:  0.0
# 197 --- ['Ą']
# Frequency:  0.0
# --------------------

# %% [markdown]
# #### Plotting similarity among most and least popular tokens

# %%
similarity_vals_popular = pos_lookup.find_similar(most_popular_tokens)
similarity_vals_least_popular = pos_lookup.find_similar(least_popular_tokens)

# %%
def plot_vals(similarity_vals):
    for i, val in enumerate(similarity_vals):

        similarity_vals_sorted = val.tolist()
        similarity_vals_sorted.sort()
        plt.plot(similarity_vals_sorted)#, label=f"POS {val}")
    plt.legend()
    plt.show()

# %%
plot_vals(similarity_vals_popular)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
similarity_vals_least_popular.shape
# Out:
# torch.Size([5, 8192])

# %%
plot_vals(similarity_vals_least_popular)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Grouping by type of POS TAG

# %%
from src.utils.data import POS_TAG_MAP

# %%
normalized_lookup_matrix = lookup_matrix + 1e-8 
normalized_lookup_matrix = normalized_lookup_matrix / normalized_lookup_matrix.sum(dim=1).unsqueeze(1)

# %%
def get_representative_token_idx_for_pos(pos_tag, comparison_factor=0.7):
    """
    returns a tuple of 
        * the indices of tokens that are primarily of a given POS tag, as well as 
        * the same indices but sorted by their frequency (descending)
    """
    primarily_pos_mask = normalized_lookup_matrix[:, POS_TAG_MAP[pos_tag]] > comparison_factor
    primarily_pos_idx = primarily_pos_mask.nonzero(as_tuple=True)[0]

    primarily_pos_idx_sorted_indices = torch.argsort(total_freq[primarily_pos_idx], descending=True)
    primarily_pos_idx_sorted = primarily_pos_idx[primarily_pos_idx_sorted_indices]

    return primarily_pos_idx, primarily_pos_idx_sorted

# %%
def print_top_representative_tokens(primarily_pos_idx_sorted):
    for i in primarily_pos_idx_sorted[:5]:
        print(i.item(), "---", tokenizer.convert_ids_to_tokens([i]))
        print("Frequency: ", total_freq[i].item())
        print("POS Distribution: ", normalized_lookup_matrix[i].numpy())
        print(10*"--")

# %%
def print_least_representative_tokens(primarily_pos_idx_sorted):
    for i in primarily_pos_idx_sorted[-5:]:
        print(i.item(), "---", tokenizer.convert_ids_to_tokens([i]))
        print("Frequency: ", total_freq[i].item())
        print("POS Distribution: ", normalized_lookup_matrix[i].numpy())
        print(10*"--")

# %%
representative_POS_tokens = { 
    tag: get_representative_token_idx_for_pos(tag) for tag in POS_TAG_MAP.keys() if tag not in ["X", "ADV"]
}

# %%
print("MOST REPRESENTATIVE TOKENS")
print(10*"--")
for tag in representative_POS_tokens.keys():
    print(tag)
    print(10*"--")
    print_top_representative_tokens(representative_POS_tokens[tag][1])
    print(10*"--")
# Out:
# MOST REPRESENTATIVE TOKENS
# --------------------
# NOUN
# --------------------
# 87 --- ['s']
# Frequency:  51957.0
# POS Distribution:  [7.42229164e-01 1.42252252e-01 5.00413813e-02 1.02007426e-02
#  6.48613274e-03 3.79159697e-03 5.73551189e-03 2.19027270e-02
#  6.35140575e-04 4.23427060e-04 1.44542605e-02 1.84768171e-03]
# --------------------
# --------------------
# 2984 --- ['Ġplus']
# Frequency:  881.0
# POS Distribution:  [4.5402952e-02 7.9455161e-03 6.1293986e-02 1.1350738e-11 1.1350738e-11
#  1.1350738e-11 5.6753689e-03 9.0805907e-03 8.6606127e-01 2.2701477e-03
#  2.2701477e-03 1.1350738e-11]
# --------------------
# --------------------
# PRT
# --------------------
# 284 --- ['Ġto']
# Frequency:  223318.0
# POS Distribution:  [2.1740299e-02 5.0645270e-03 4.6212128e-03 8.5080467e-04 1.3433758e-03
#  1.3388979e-03 1.5851834e-03 9.9051576e-03 1.8807262e-04 9.4182736e-01
#  1.1436606e-02 9.8514225e-05]
# --------------------
# 443 --- ['Ġup']
# Frequency:  26165.0
# POS Distribution:  [2.4192624e-02 1.0128033e-02 1.6701700e-02 1.5524556e-01 1.1847889e-03
#  8.4081787e-04 6.5660231e-02 3.6690235e-03 3.8218994e-13 7.1026182e-01
#  1.2077202e-02 3.8218994e-05]
# --------------------
# --------------------
# .
# --------------------
# 18 --- ['.']
# Frequency:  711862.0
# POS Distribution:  [1.0117129e-02 2.6845091e-03 3.0918913e-03 5.3802563e-04 8.5550291e-04
#  1.5438385e-03 1.1715754e-03 1.2550185e-02 1.8121490e-04 1.7559584e-04
#  9.6702451e-01 6.6024033e-05]
# --------------------
# 16 --- [',']
# Frequency:  554378.0
# POS Distribution:  [1.59007031e-02 3.38397268e-03 3.69603420e-03 9.43399617e-04
#  1.12017430e-03 1.45929307e-03 1.75512012e-03 1.23020755e-02
#  2.27281751e-04 2.75984989e-04 9.58890855e-01 4.50955849e-05]
# --------------------
# 35 --- ['?']
# Frequency:  146507.0
# POS Distribution:  [3.9998088e-03 1.9043458e-03 1.9316484e-03 2.8667573e-04 4.2318797e-04
#  2.3207082e-04 6.0747948e-04 1.6381469e-04 2.0476837e-05 8.1907347e-05
#  9.9032128e-01 2.7302449e-05]
# --------------------
# 5 --- ['!']
# Frequency:  61103.0
# POS Distribution:  [1.1717919e-02 4.5660604e-03 3.1749669e-03 4.9097429e-04 6.0553494e-04
#  2.9458455e-04 6.8736396e-04 3.4368198e-04 8.1829043e-05 3.1095036e-04
#  9.7754610e-01 1.8002390e-04]
# --------------------
# 17 --- ['-']
# Frequency:  58076.0
# POS Distribution:  [2.0628143e-02 4.9762381e-03 1.0004132e-02 1.7563193e-03 1.4291618e-03
#  9.4531300e-03 4.2874855e-03 2.2005647e-02 2.0662580e-04 1.8940699e-04
#  9.2494315e-01 1.2053172e-04]
# --------------------
# --------------------

# %%
print("LEAST REPRESENTATIVE TOKENS")
print(10*"--")
for tag in representative_POS_tokens.keys():
    print(tag)
    print(10*"--")
    print_least_representative_tokens(representative_POS_tokens[tag][1])
    print(10*"--")
# Out:
# LEAST REPRESENTATIVE TOKENS
# --------------------
# NOUN
# --------------------
# 1692 --- ['Ġdaught']
# Frequency:  1.0
# POS Distribution:  [1.e+00 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08
#  1.e-08 1.e-08]
# --------------------
# 5920 --- ['iggler']
# Frequency:  1.0
# POS Distribution:  [1.e+00 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08
#  1.e-08 1.e-08]
# --------------------
# 6498 --- ['celer']
# Frequency:  1.0
# POS Distribution:  [1.e+00 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08
#  1.e-08 1.e-08]
# --------------------
# 5721 --- ['Ġembarr']
# Frequency:  1.0
# POS Distribution:  [1.e+00 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08
#  1.e-08 1.e-08]
# --------------------
# 5806 --- ['Ġmassachus']
# Frequency:  1.0
# POS Distribution:  [1.e+00 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08
#  1.e-08 1.e-08]
# --------------------
# --------------------
# VERB
# --------------------
# 1915 --- ['Ġcharac']
# Frequency:  7.0
# POS Distribution:  [2.8571430e-01 7.1428573e-01 1.4285714e-09 1.4285714e-09 1.4285714e-09
#  1.4285714e-09 1.4285714e-09 1.4285714e-09 1.4285714e-09 1.4285714e-09
#  1.4285714e-09 1.4285714e-09]
# --------------------
# 7040 --- ['esome']
# Frequency:  4.0
# POS Distribution:  [2.5e-01 7.5e-01 2.5e-09 2.5e-09 2.5e-09 2.5e-09 2.5e-09 2.5e-09 2.5e-09
#  2.5e-09 2.5e-09 2.5e-09]
# --------------------
# 1120 --- ['Ġinclud']
# Frequency:  1.0
# POS Distribution:  [1.e-08 1.e+00 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08
#  1.e-08 1.e-08]
# --------------------
# 2978 --- ['Ġobv']
# Frequency:  1.0
# POS Distribution:  [1.e-08 1.e+00 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08
#  1.e-08 1.e-08]
# --------------------
# 3835 --- ['Ġresour']
# Frequency:  1.0
# POS Distribution:  [1.e-08 1.e+00 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08 1.e-08
#  1.e-08 1.e-08]
# --------------------
# --------------------
# ADJ
# --------------------
# 148 --- ['Ó']
# Frequency:  4.0
# POS Distribution:  [2.5e-09 2.5e-09 1.0e+00 2.5e-09 2.5e-09 2.5e-09 2.5e-09 2.5e-09 2.5e-09
#  2.5e-09 2.5e-09 2.5e-09]
# --------------------
# 4416 --- ['partement']
# Frequency:  2.0
# POS Distribution:  [5.e-09 5.e-09 1.e+00 5.e-09 5.e-09 5.e-09 5.e-09 5.e-09 5.e-09 5.e-09
#  5.e-09 5.e-09]
# --------------------
# 4528 --- ['Ġstrug']
# Frequency:  1.0
# POS Distribution:  [9.999999e-09 9.999999e-09 9.999999e-01 9.999999e-09 9.999999e-09
#  9.999999e-09 9.999999e-09 9.999999e-09 9.999999e-09 9.999999e-09
#  9.999999e-09 9.999999e-09]
# --------------------
# 4652 --- ['Ġinstr']
# Frequency:  1.0
# POS Distribution:  [9.999999e-09 9.999999e-09 9.999999e-01 9.999999e-09 9.999999e-09
#  9.999999e-09 9.999999e-09 9.999999e-09 9.999999e-09 9.999999e-09
#  9.999999e-09 9.999999e-09]
# --------------------
# 6857 --- ['intendo']
# Frequency:  1.0
# POS Distribution:  [9.999999e-09 9.999999e-09 9.999999e-01 9.999999e-09 9.999999e-09
#  9.999999e-09 9.999999e-09 9.999999e-09 9.999999e-09 9.999999e-09
#  9.999999e-09 9.999999e-09]
# --------------------
# --------------------
# PRON
# --------------------
# 2678 --- ['Ġwhose']
# Frequency:  1047.0
# POS Distribution:  [1.8147087e-02 4.7755493e-03 9.5510983e-04 9.5510983e-04 9.5606494e-01
#  9.5510986e-12 2.8653296e-03 8.5959882e-03 9.5510986e-12 9.5510986e-12
#  7.6408787e-03 9.5510986e-12]
# --------------------
# 2724 --- ['Ġherself']
# Frequency:  1019.0
# POS Distribution:  [1.0304220e-01 7.9489693e-02 4.9067712e-03 1.9627085e-03 7.5269872e-01
#  2.9440627e-03 1.9627085e-03 3.9254171e-03 9.8135423e-12 9.8135427e-04
#  4.7105003e-02 9.8135427e-04]
# --------------------
# 2815 --- ['Ġwhom']
# Frequency:  970.0
# POS Distribution:  [3.91752571e-02 3.09278350e-03 1.13402065e-02 3.09278350e-03
#  8.93814445e-01 3.09278350e-03 3.09278350e-03 1.03092780e-02
#  1.03092786e-11 1.03092786e-11 3.29896919e-02 1.03092786e-11]
# --------------------
# 4281 --- ['who']
# Frequency:  499.0
# POS Distribution:  [7.6152302e-02 2.6052104e-02 2.8056113e-02 1.0020040e-02 7.9158318e-01
#  4.0080161e-03 6.0120239e-03 1.6032064e-02 2.0040081e-11 2.0040081e-11
#  4.2084169e-02 2.0040081e-11]
# --------------------
# 4570 --- ['they']
# Frequency:  452.0
# POS Distribution:  [4.2035397e-02 4.4247787e-03 2.2123894e-02 4.4247787e-03 8.9823008e-01
#  2.2123894e-03 6.6371681e-03 4.4247787e-03 2.2123893e-11 2.2123893e-11
#  1.5486726e-02 2.2123893e-11]
# --------------------
# --------------------
# DET
# --------------------
# 4101 --- ['ĠpyrÃ©nÃ©es']
# Frequency:  536.0
# POS Distribution:  [1.8656717e-11 1.8656717e-11 1.8656716e-03 1.8656717e-11 1.8656717e-11
#  7.9477614e-01 1.8656716e-03 1.8656717e-11 1.8656717e-11 1.8656717e-11
#  2.0149253e-01 1.8656717e-11]
# --------------------
# 4115 --- ['atlantiques']
# Frequency:  533.0
# POS Distribution:  [1.8761727e-11 1.8761727e-11 1.8761726e-03 1.8761727e-11 1.8761727e-11
#  7.9362100e-01 1.8761726e-03 1.8761727e-11 1.8761727e-11 1.8761727e-11
#  2.0262665e-01 1.8761727e-11]
# --------------------
# 4144 --- ['Ġsouthwestern']
# Frequency:  527.0
# POS Distribution:  [5.69259981e-03 1.89753317e-11 1.21442124e-01 1.89753317e-11
#  1.89753317e-11 7.66603410e-01 1.89753317e-11 1.89753319e-03
#  1.89753317e-11 1.89753317e-11 1.04364328e-01 1.89753317e-11]
# --------------------
# 4432 --- ['dÃ©partement']
# Frequency:  478.0
# POS Distribution:  [6.9037654e-02 4.1841003e-03 1.6736401e-02 2.0920501e-11 2.0920501e-11
#  7.9916316e-01 2.0920501e-11 2.0920501e-11 2.0920501e-11 2.0920501e-11
#  1.1087866e-01 2.0920501e-11]
# --------------------
# 6331 --- ['which']
# Frequency:  267.0
# POS Distribution:  [4.4943821e-02 1.1235955e-02 2.6217228e-02 3.7453183e-11 3.7453183e-11
#  8.6516851e-01 3.7453183e-11 2.9962547e-02 3.7453184e-03 3.7453183e-11
#  1.8726591e-02 3.7453183e-11]
# --------------------
# --------------------
# ADP
# --------------------
# 5029 --- ['Ġunlike']
# Frequency:  385.0
# POS Distribution:  [1.2987013e-02 5.1948051e-03 2.0259741e-01 1.0389610e-02 2.5974025e-03
#  2.5974025e-11 7.4285716e-01 2.3376623e-02 2.5974025e-11 2.5974025e-11
#  2.5974025e-11 2.5974025e-11]
# --------------------
# 5456 --- ['Ġvia']
# Frequency:  340.0
# POS Distribution:  [3.2352943e-02 2.9411765e-11 3.2352943e-02 2.9411765e-11 2.9411765e-11
#  2.9411765e-11 9.0588236e-01 2.3529412e-02 2.9411765e-11 2.9411765e-11
#  5.8823531e-03 2.9411765e-11]
# --------------------
# 7050 --- ['from']
# Frequency:  227.0
# POS Distribution:  [1.1894273e-01 4.8458152e-02 2.6431719e-02 1.3215859e-02 4.4052862e-11
#  4.4052862e-11 7.3568285e-01 3.5242289e-02 4.4052862e-11 4.4052862e-03
#  1.7621145e-02 4.4052862e-11]
# --------------------
# 2258 --- ['though']
# Frequency:  64.0
# POS Distribution:  [4.68750e-02 1.56250e-10 1.56250e-02 3.12500e-02 1.56250e-10 3.12500e-02
#  8.59375e-01 1.56250e-02 1.56250e-10 1.56250e-10 1.56250e-10 1.56250e-10]
# --------------------
# 226 --- ['ġ']
# Frequency:  1.0
# POS Distribution:  [9.999999e-09 9.999999e-09 9.999999e-09 9.999999e-09 9.999999e-09
#  9.999999e-09 9.999999e-01 9.999999e-09 9.999999e-09 9.999999e-09
#  9.999999e-09 9.999999e-09]
# --------------------
# --------------------
# NUM
# --------------------
# 747 --- ['Ġ201']
# Frequency:  23.0
# POS Distribution:  [4.347826e-10 4.347826e-10 4.347826e-10 4.347826e-10 4.347826e-10
#  4.347826e-10 4.347826e-10 1.000000e+00 4.347826e-10 4.347826e-10
#  4.347826e-10 4.347826e-10]
# --------------------
# 1118 --- ['Ġ199']
# Frequency:  12.0
# POS Distribution:  [8.3333336e-02 8.3333335e-10 8.3333335e-10 8.3333335e-10 8.3333335e-10
#  8.3333335e-10 8.3333335e-10 9.1666669e-01 8.3333335e-10 8.3333335e-10
#  8.3333335e-10 8.3333335e-10]
# --------------------
# 1561 --- ['Ġ196']
# Frequency:  11.0
# POS Distribution:  [9.090909e-10 9.090909e-10 9.090909e-10 9.090909e-10 9.090909e-10
#  9.090909e-10 9.090909e-10 1.000000e+00 9.090909e-10 9.090909e-10
#  9.090909e-10 9.090909e-10]
# --------------------
# 1416 --- ['Ġ197']
# Frequency:  10.0
# POS Distribution:  [1.e-09 1.e-09 1.e-09 1.e-09 1.e-09 1.e-09 1.e-09 1.e+00 1.e-09 1.e-09
#  1.e-09 1.e-09]
# --------------------
# 1312 --- ['Ġ198']
# Frequency:  9.0
# POS Distribution:  [1.1111111e-09 1.1111111e-09 1.1111111e-09 1.1111111e-09 1.1111111e-09
#  1.1111111e-09 1.1111111e-09 1.0000000e+00 1.1111111e-09 1.1111111e-09
#  1.1111111e-09 1.1111111e-09]
# --------------------
# --------------------
# CONJ
# --------------------
# 388 --- ['Ġbut']
# Frequency:  44372.0
# POS Distribution:  [1.8750563e-02 4.1242223e-03 3.8087082e-03 7.4371224e-04 1.6902551e-03
#  1.3747409e-03 1.4648878e-03 4.2819795e-03 9.4742179e-01 1.5775714e-04
#  1.6113766e-02 6.7610206e-05]
# --------------------
# 425 --- ['Ġor']
# Frequency:  26560.0
# POS Distribution:  [5.4028615e-02 6.9277110e-03 1.1295181e-02 1.5436747e-03 1.8825302e-03
#  1.5436747e-03 2.5602409e-03 8.7725902e-03 9.0229666e-01 3.7650601e-04
#  8.4713856e-03 3.0120483e-04]
# --------------------
# 1483 --- ['but']
# Frequency:  1473.0
# POS Distribution:  [1.6768500e-01 2.1045486e-02 2.1045486e-02 2.7155464e-03 4.0733200e-03
#  2.0366600e-03 4.7522062e-03 5.4310928e-03 7.3794979e-01 6.7888663e-12
#  3.2586560e-02 6.7888660e-04]
# --------------------
# 2984 --- ['Ġplus']
# Frequency:  881.0
# POS Distribution:  [4.5402952e-02 7.9455161e-03 6.1293986e-02 1.1350738e-11 1.1350738e-11
#  1.1350738e-11 5.6753689e-03 9.0805907e-03 8.6606127e-01 2.2701477e-03
#  2.2701477e-03 1.1350738e-11]
# --------------------
# 3545 --- ['Ġ&']
# Frequency:  671.0
# POS Distribution:  [1.6393442e-02 1.1922504e-02 1.4903130e-03 4.4709388e-03 1.4903129e-11
#  4.4709388e-03 1.4903130e-03 3.1296574e-02 9.2101341e-01 1.4903129e-11
#  7.4515650e-03 1.4903129e-11]
# --------------------
# --------------------
# PRT
# --------------------
# 284 --- ['Ġto']
# Frequency:  223318.0
# POS Distribution:  [2.1740299e-02 5.0645270e-03 4.6212128e-03 8.5080467e-04 1.3433758e-03
#  1.3388979e-03 1.5851834e-03 9.9051576e-03 1.8807262e-04 9.4182736e-01
#  1.1436606e-02 9.8514225e-05]
# --------------------
# 443 --- ['Ġup']
# Frequency:  26165.0
# POS Distribution:  [2.4192624e-02 1.0128033e-02 1.6701700e-02 1.5524556e-01 1.1847889e-03
#  8.4081787e-04 6.5660231e-02 3.6690235e-03 3.8218994e-13 7.1026182e-01
#  1.2077202e-02 3.8218994e-05]
# --------------------
# --------------------
# .
# --------------------
# 119 --- ['¶']
# Frequency:  64.0
# POS Distribution:  [1.40625e-01 1.56250e-10 9.37500e-02 1.56250e-10 1.56250e-10 1.56250e-10
#  1.56250e-02 1.56250e-10 1.56250e-10 1.56250e-10 7.50000e-01 1.56250e-10]
# --------------------
# 173 --- ['ì']
# Frequency:  41.0
# POS Distribution:  [1.4634146e-01 2.4390243e-10 2.4390243e-10 2.4390243e-10 2.4390243e-10
#  2.4390243e-10 2.4390243e-10 7.3170729e-02 2.4390243e-10 2.4390243e-10
#  7.8048778e-01 2.4390243e-10]
# --------------------
# 95 --- ['{']
# Frequency:  36.0
# POS Distribution:  [1.1111111e-01 2.7777777e-10 2.7777777e-10 2.7777777e-10 2.7777777e-10
#  2.7777777e-10 2.7777777e-10 2.7777777e-10 2.7777777e-10 2.7777778e-02
#  8.6111110e-01 2.7777777e-10]
# --------------------
# 172 --- ['ë']
# Frequency:  26.0
# POS Distribution:  [1.5384616e-01 3.8461540e-10 3.8461540e-10 3.8461540e-10 3.8461540e-10
#  3.8461540e-10 3.8461540e-10 3.8461540e-10 3.8461540e-10 3.8461540e-10
#  8.4615386e-01 3.8461540e-10]
# --------------------
# 151 --- ['Ö']
# Frequency:  15.0
# POS Distribution:  [1.3333334e-01 6.6666667e-10 6.6666670e-02 6.6666667e-10 6.6666667e-10
#  6.6666667e-10 6.6666667e-10 6.6666667e-10 6.6666667e-10 6.6666667e-10
#  8.0000001e-01 6.6666667e-10]
# --------------------
# --------------------

# %% [markdown]
# We now plot for each of the most popular tokens that are representative of each POS tag how those representative tokens distribute their similarity to other tokens

# %%
fig, axs = plt.subplots(len(representative_POS_tokens), 1, figsize=(15, 50))

num_from_each = 1

for plot_idx, (tag, (tag_idx, tag_idx_sorted)) in enumerate(representative_POS_tokens.items()):

    if num_from_each*2 >= len(tag_idx_sorted):
        sample_idx = torch.cat([
            torch.arange(0, num_from_each),
            torch.arange(len(tag_idx_sorted)-num_from_each, len(tag_idx_sorted))
        ])
    else:
        sample_idx = torch.cat([
            torch.arange(0, num_from_each),
            torch.arange(len(tag_idx_sorted)-num_from_each, len(tag_idx_sorted)),
            torch.randint(num_from_each, len(tag_idx_sorted)-num_from_each, (num_from_each,))
        ])

    pos_reprs = tag_idx_sorted[sample_idx]
    pos_reprs_sim_dist = pos_lookup.find_similar(pos_reprs)
    
    for i, val in enumerate(pos_reprs_sim_dist):

        # For the first num_from_each (top) make like solid, for the next num_from_each (bottom) make like dashed, for the rest dotted
        line_style = "-" if i < num_from_each else "--" if i < num_from_each*2 else "-."
        label = "top" if i < num_from_each else "bottom" if i < num_from_each*2 else "middle"

        similarity_vals_sorted = val.tolist()
        similarity_vals_sorted.sort()
        axs[plot_idx].plot(similarity_vals_sorted, linestyle=line_style, label=label)

    axs[plot_idx].set_title(tag)
    axs.flat[plot_idx].legend()

plt.legend()
plt.show()

# %%
temp_parameter = 0.025

fig, axs = plt.subplots(len(representative_POS_tokens), 1, figsize=(15, 50))

num_from_each = 1

for plot_idx, (tag, (tag_idx, tag_idx_sorted)) in enumerate(representative_POS_tokens.items()):

    if num_from_each*2 >= len(tag_idx_sorted):
        sample_idx = torch.cat([
            torch.arange(0, num_from_each),
            torch.arange(len(tag_idx_sorted)-num_from_each, len(tag_idx_sorted))
        ])
    else:
        sample_idx = torch.cat([
            torch.arange(0, num_from_each),
            torch.arange(len(tag_idx_sorted)-num_from_each, len(tag_idx_sorted)),
            torch.randint(num_from_each, len(tag_idx_sorted)-num_from_each, (num_from_each,))
        ])

    pos_reprs = tag_idx_sorted[sample_idx]
    pos_reprs_sim_dist = pos_lookup.find_similar(pos_reprs)

    # apply the temperature parameter
    pos_reprs_sim_dist = torch.exp(pos_reprs_sim_dist / temp_parameter)
    pos_reprs_sim_dist = pos_reprs_sim_dist / pos_reprs_sim_dist.sum(dim=1).unsqueeze(1)
    
    for i, val in enumerate(pos_reprs_sim_dist):

        # For the first num_from_each (top) make like solid, for the next num_from_each (bottom) make like dashed, for the rest dotted
        line_style = "-" if i < num_from_each else "--" if i < num_from_each*2 else "-."
        label = "top" if i < num_from_each else "bottom" if i < num_from_each*2 else "middle"

        similarity_vals_sorted = val.tolist()
        similarity_vals_sorted.sort()
        axs[plot_idx].plot(similarity_vals_sorted, linestyle=line_style, label=label)

    axs[plot_idx].set_title(tag)
    axs.flat[plot_idx].legend()

plt.legend()
plt.show()
